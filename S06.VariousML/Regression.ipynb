# %% [markdown]
# # Regression

# %% [markdown]
# ## Reading data

# %%
from sklearn import datasets

boston = datasets.load_boston()
# Out:
# /Users/takamatsunaoki/opt/anaconda3/envs/ai-master/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# ...

# %% [markdown]
# ## Training and testing data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.2, random_state=0)

# %% [markdown]
# ## Build Linear regression model

# %%
from sklearn.linear_model import LinearRegression

# get the RM column
X_rm_train = X_train[:, 5]
X_rm_train = X_rm_train.reshape(-1, 1)
X_rm_test = X_test[:, 5]
X_rm_test = X_rm_test.reshape(-1, 1)

model = LinearRegression()
model.fit(X_rm_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Plot the data of Linear regression

# %%
import matplotlib.pyplot as plt

plt.scatter(X_rm_train, y_train, label='Train')
plt.scatter(X_rm_test, y_test, label='Test')

y_reg = lr.predict(X_rm_train)
plt.plot(X_rm_train, y_reg, label='Regression', color='red')

plt.xlabel('RM')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluation of Linear regression

# %%
from sklearn.metrics import mean_squared_error

y_train_pred = lr.predict(X_rm_train)
mse_train = mean_squared_error(y_train, y_train_pred)
print("MSE(Train)", mse_train)

y_test_pred = lr.predict(X_rm_test)
mse_test = mean_squared_error(y_test, y_test_pred)
print("MSE(Test)", mse_test)
# Out:
# MSE(Train) 42.82047894172751
# MSE(Test) 46.907351627395315

# %% [markdown]
# ## Build Polynomial regression model

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluation of Polynomial regression

# %%
y_train_pred = model.predict(X_train)
mse_train = mean_squared_error(y_train, y_train_pred)
print("MSE(Train)", mse_train)

y_test_pred = model.predict(X_test)
mse_test = mean_squared_error(y_test, y_test_pred)
print("MSE(Test)", mse_test)
# Out:
# MSE(Train) 19.326470203585725
# MSE(Test) 33.44897999767653
