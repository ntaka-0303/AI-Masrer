# %% [markdown]
# # Suport Vector Machine

# %% [markdown]
# ## Read data

# %%
from sklearn.datasets import load_wine

wine = load_wine()
X = wine.data
y = wine.target

# %% [markdown]
# ## Training and testing data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Build the model

# %%
from sklearn.svm import SVC

model = SVC()
model.fit(X_train_scaled, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Predict & Evaluate

# %%
y_train_pred = model.predict(X_train_scaled)
y_test_pred = model.predict(X_test_scaled)

from sklearn.metrics import accuracy_score

acc_train = accuracy_score(y_train, y_train_pred)
acc_test = accuracy_score(y_test, y_test_pred)
print('Training accuracy: {:.3f}'.format(acc_train))
print('Test accuracy: {:.3f}'.format(acc_test))
# Out:
# Training accuracy: 0.992
# Test accuracy: 1.000

# %% [markdown]
# ## Visualize the result

# %%
import matplotlib.pyplot as plt
import numpy as np

axis_1=0
axis_2=1

x = np.concatenate((X_train_scaled, X_test_scaled))
y = np.concatenate((y_train, y_test))
y_pred = np.concatenate((y_train_pred, y_test_pred))

group_0 = x[y==0]
plt.scatter(group_0[:,axis_1], group_0[:,axis_2], c='blue', label='class 0')

group_1 = x[y==1]
plt.scatter(group_1[:,axis_1], group_1[:,axis_2], c='red', label='class 1')

group_2 = x[y==2]
plt.scatter(group_2[:,axis_1], group_2[:,axis_2], c='green', label='class 2')

plt.xlabel(wine.feature_names[axis_1])
plt.ylabel(wine.feature_names[axis_2])
plt.legend()
plt.show()
