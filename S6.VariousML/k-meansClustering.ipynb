# %% [markdown]
# # k-menas Clustering

# %% [markdown]
# ## Read the data

# %%
from sklearn.cluster import KMeans
from sklearn import datasets

# Load the iris dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ## Build the model

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=3, random_state=0)
model.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %% [markdown]
# ## Plot the clusters

# %%
import matplotlib.pyplot as plt

axis_1 = 2
axis_2 = 3

group_0 = X[model.labels_ == 0]
plt.scatter(group_0[:, axis_1], group_0[:, axis_2], color='red')

group_1 = X[model.labels_ == 1]
plt.scatter(group_1[:, axis_1], group_1[:, axis_2], color='green')

group_2 = X[model.labels_ == 2]
plt.scatter(group_2[:, axis_1], group_2[:, axis_2], color='blue')

plt.xlabel(iris.feature_names[axis_1])
plt.ylabel(iris.feature_names[axis_2])
plt.show()

# %%
axis_1 = 2
axis_2 = 3

group_0 = X[y == 0]
plt.scatter(group_0[:, axis_1], group_0[:, axis_2], color='red')

group_1 = X[y == 1]
plt.scatter(group_1[:, axis_1], group_1[:, axis_2], color='green')

group_2 = X[y == 2]
plt.scatter(group_2[:, axis_1], group_2[:, axis_2], color='blue')

plt.xlabel(iris.feature_names[axis_1])
plt.ylabel(iris.feature_names[axis_2])
plt.show()
