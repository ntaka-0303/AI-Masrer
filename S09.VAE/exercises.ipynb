# %% [markdown]
# # Exerciese

# %% [markdown]
# ## Create the training data

# %%
import numpy as np
from keras.datasets import mnist

# Load the data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the data
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %% [markdown]
# ## Setting up the hyperparameters

# %%
epochs = 50
batch_size = 256
n_in_out = 784
n_hidden = 256
n_z = 2

# %% [markdown]
# ## Create the model

# %%
from keras.models import Model
from keras import metrics
from keras.layers import Input, Dense, Lambda
from keras import backend as K

# Function for sampling latent variables
def sampling(args):
    mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(log_var), mean=0., stddev=1.)
    return mu + K.exp(log_var / 2) * epsilon

# Create the VAE network
x = Input(shape=(n_in_out))
h = Dense(n_hidden, activation='relu')(x)

mu = Dense(n_z)(h)
log_var = Dense(n_z)(h)
z = Lambda(sampling, output_shape=(n_z,))([mu, log_var])

decoder_h = Dense(n_hidden, activation='relu')
h_decoded = decoder_h(z)
decoder_mean = Dense(n_in_out, activation='sigmoid')
y = decoder_mean(h_decoded)

# Create the VAE model
vae = Model(x, y)

# loss function
rec_loss = n_in_out * metrics.binary_crossentropy(x, y)
kl_loss = - 0.5 * K.sum(1 + log_var - K.square(mu) - K.exp(log_var), axis=-1)
vae_loss = K.mean(rec_loss + kl_loss)

vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 784)]        0           []
#
#  dense_5 (Dense)                (None, 256)          200960      ['input_3[0][0]']
#
#  dense_6 (Dense)                (None, 2)            514         ['dense_5[0][0]']
#
#  dense_7 (Dense)                (None, 2)            514         ['dense_5[0][0]']
#
#  lambda_1 (Lambda)              (None, 2)            0           ['dense_6[0][0]',
#                                                                   'dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 256)          768         ['lambda_1[0][0]']
#
#  dense_9 (Dense)                (None, 784)          201488      ['dense_8[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 2)           0           ['dense_7[0][0]']
#  mbda)
#
#  tf.math.square_1 (TFOpLambda)  (None, 2)            0           ['dense_6[0][0]']
#
#  tf.cast_1 (TFOpLambda)         (None, 784)          0           ['input_3[0][0]']
#
#  tf.convert_to_tensor_3 (TFOpLa  (None, 784)         0           ['dense_9[0][0]']
#  mbda)
#
#  tf.math.subtract_2 (TFOpLambda  (None, 2)           0           ['tf.__operators__.add_2[0][0]',
#  )                                                                'tf.math.square_1[0][0]']
#
#  tf.math.exp_1 (TFOpLambda)     (None, 2)            0           ['dense_7[0][0]']
#
#  tf.keras.backend.binary_crosse  (None, 784)         0           ['tf.cast_1[0][0]',
#  ntropy_1 (TFOpLambda)                                            'tf.convert_to_tensor_3[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 2)           0           ['tf.math.subtract_2[0][0]',
#  )                                                                'tf.math.exp_1[0][0]']
#
#  tf.math.reduce_mean_2 (TFOpLam  (None,)             0           ['tf.keras.backend.binary_crossen
#  bda)                                                            tropy_1[0][0]']
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None,)             0           ['tf.math.subtract_3[0][0]']
#  da)
#
#  tf.math.multiply_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_mean_2[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_1[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None,)             0           ['tf.math.multiply_2[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.math.reduce_mean_3 (TFOpLam  ()                  0           ['tf.__operators__.add_3[0][0]']
#  bda)
#
#  add_loss_1 (AddLoss)           ()                   0           ['tf.math.reduce_mean_3[0][0]']
#
# ==================================================================================================
# Total params: 404,244
# Trainable params: 404,244
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# 235/235 [==============================] - 8s 34ms/step - loss: 153.0470 - val_loss: 154.1656
# Epoch 29/50
# 235/235 [==============================] - 11s 48ms/step - loss: 152.7988 - val_loss: 153.9456
# Epoch 30/50
# 235/235 [==============================] - 9s 38ms/step - loss: 152.5525 - val_loss: 153.7861
# Epoch 31/50
# 235/235 [==============================] - 7s 31ms/step - loss: 152.3233 - val_loss: 153.5339
# Epoch 32/50
# 235/235 [==============================] - 9s 38ms/step - loss: 152.1314 - val_loss: 153.4651
# Epoch 33/50
# 235/235 [==============================] - 9s 37ms/step - loss: 151.9323 - val_loss: 153.3820
# Epoch 34/50
# 235/235 [==============================] - 7s 28ms/step - loss: 151.7652 - val_loss: 153.0324
# Epoch 35/50
# 235/235 [==============================] - 10s 42ms/step - loss: 151.5908 - val_loss: 153.0357
# Epoch 36/50
# 235/235 [==============================] - 10s 40ms/step - loss: 151.4021 - val_loss: 153.0591
# Epoch 37/50
# 235/235 [==============================] - 10s 44ms/step - loss: 151.2669 - val_loss: 152.7231
# Epoch 38/50
# 235/235 [==============================] - 10s 44ms/step - loss: 151.0989 - val_loss: 152.8213
# Epoch 39/50
# 235/235 [==============================] - 7s 30ms/step - loss: 150.9249 - val_loss: 152.6668
# Epoch 40/50
# 235/235 [==============================] - 7s 28ms/step - loss: 150.7883 - val_loss: 152.6295
# Epoch 41/50
# 235/235 [==============================] - 8s 35ms/step - loss: 150.6628 - val_loss: 152.7410
# Epoch 42/50
# 235/235 [==============================] - 11s 46ms/step - loss: 150.5028 - val_loss: 152.5991
# Epoch 43/50
# 235/235 [==============================] - 12s 49ms/step - loss: 150.3337 - val_loss: 152.4168
# Epoch 44/50
# 235/235 [==============================] - 12s 53ms/step - loss: 150.2450 - val_loss: 152.2458
# Epoch 45/50
# 235/235 [==============================] - 11s 45ms/step - loss: 150.0925 - val_loss: 152.2388
# Epoch 46/50
# 235/235 [==============================] - 11s 48ms/step - loss: 150.0291 - val_loss: 152.4408
# Epoch 47/50
# 235/235 [==============================] - 10s 41ms/step - loss: 149.8920 - val_loss: 151.9004
# Epoch 48/50
# 235/235 [==============================] - 10s 44ms/step - loss: 149.7370 - val_loss: 152.0100
# Epoch 49/50
# 235/235 [==============================] - 10s 40ms/step - loss: 149.6320 - val_loss: 151.8277
# Epoch 50/50
# 235/235 [==============================] - 9s 40ms/step - loss: 149.5862 - val_loss: 151.8623

# %% [markdown]
# ## Visualize the latent space

# %%
# Model for latent variables
encoder = Model(x, z)

# plot latent variables
import matplotlib.pyplot as plt

z_train = encoder.predict(x_train, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(z_train[:, 0], z_train[:, 1], c=y_train)
plt.title("Training Latent variables")
plt.colorbar()
plt.show()

# Model for decoded images
z_test = encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(z_test[:, 0], z_test[:, 1], c=y_test)
plt.title("Test Latent variables")
plt.colorbar()
plt.show()
# Out:
# 235/235 [==============================] - 3s 9ms/step
# 40/40 [==============================] - 1s 14ms/step

# %% [markdown]
# ## Generate new images

# %%
# Generator for new images
input_decoder = Input(shape=(n_z,))
decoder_h = decoder_h(input_decoder)
y = decoder_mean(decoder_h)
generator = Model(input_decoder, y)

# Setting the plot parameters
n = 16
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

# Sampling the latent variables
grid_x = np.linspace(5, -5, n)
grid_y = np.linspace(-5, 5, n)

# Generating the images
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

# Plotting the images
plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 704ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 448ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 474ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 948ms/step
